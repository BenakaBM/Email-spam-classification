# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv(r"C:\Users\Madhu Sudhan\Desktop\Dataset\mail_data.csv")
df
# Out:
#      Category                                            Message
# 0         ham  Go until jurong point, crazy.. Available only ...
# 1         ham                      Ok lar... Joking wif u oni...
# 2        spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         ham  U dun say so early hor... U c already then say...
# 4         ham  Nah I don't think he goes to usf, he lives aro...
# ...       ...                                                ...
# 5567     spam  This is the 2nd time we have tried 2 contact u...
# 5568      ham               Will ü b going to esplanade fr home?
# 5569      ham  Pity, * was in mood for that. So...any other s...
# 5570      ham  The guy did some bitching but I acted like i'd...
# 5571      ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# Category    0
# Message     0
# dtype: int64

# %%
df.head(5)
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.shape
# Out:
# (5572, 2)

# %%
df.loc[df['Category'] == "spam", "Category"] = 0
df.loc[df['Category'] == "ham", "Category"] = 1

# %%
x = df['Message']
y = df['Category']

# %%
x
# Out:
# 0       Go until jurong point, crazy.. Available only ...
# 1                           Ok lar... Joking wif u oni...
# 2       Free entry in 2 a wkly comp to win FA Cup fina...
# 3       U dun say so early hor... U c already then say...
# 4       Nah I don't think he goes to usf, he lives aro...
#                               ...
# 5567    This is the 2nd time we have tried 2 contact u...
# 5568                 Will ü b going to esplanade fr home?
# 5569    Pity, * was in mood for that. So...any other s...
# 5570    The guy did some bitching but I acted like i'd...
# 5571                           Rofl. Its true to its name
# Name: Message, Length: 5572, dtype: object

# %%
y
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 5567    0
# 5568    1
# 5569    1
# 5570    1
# 5571    1
# Name: Category, Length: 5572, dtype: object

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=3)

print(x.shape)
print(x_train.shape)
# Out:
# (5572,)
# (4457,)

# %%
from sklearn.preprocessing import StandardScaler,LabelEncoder

vectorizer = TfidfVectorizer(min_df = 1, stop_words='english', lowercase = True)

x_train_vec = vectorizer.fit_transform(x_train)

x_test_vec = vectorizer.transform(x_test)

print(x_train_vec)

print("Training Data Vector Shape:", x_train_vec.shape)
print("Test Data Vector Shape:", x_test_vec.shape)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 34775 stored elements and shape (4457, 7431)>
#   Coords	Values
#   (0, 2329)	0.38783870336935383
#   (0, 3811)	0.34780165336891333
#   (0, 2224)	0.413103377943378
#   (0, 4456)	0.4168658090846482
#   (0, 5413)	0.6198254967574347
#   (1, 3811)	0.17419952275504033
#   (1, 3046)	0.2503712792613518
#   (1, 1991)	0.33036995955537024
#   (1, 2956)	0.33036995955537024
#   (1, 2758)	0.3226407885943799
#   (1, 1839)	0.2784903590561455
#   (1, 918)	0.22871581159877646
#   (1, 2746)	0.3398297002864083
#   (1, 2957)	0.3398297002864083
#   (1, 3325)	0.31610586766078863
#   (1, 3185)	0.29694482957694585
#   (1, 4080)	0.18880584110891163
#   (2, 6601)	0.6056811524587518
#   (2, 2404)	0.45287711070606745
#   (2, 3156)	0.4107239318312698
#   (2, 407)	0.509272536051008
#   (3, 7414)	0.8100020912469564
#   (3, 2870)	0.5864269879324768
#   (4, 2870)	0.41872147309323743
#   (4, 487)	0.2899118421746198
#   :	:
# ...

# %%
y_train = y_train.astype('int')
y_test = y_test.astype('int')

print(y_train)
# Out:
# 3075    1
# 1787    1
# 1614    1
# 4304    1
# 3266    0
#        ..
# 789     0
# 968     1
# 1667    1
# 3321    1
# 1688    0
# Name: Category, Length: 4457, dtype: int64

# %%
log_reg = LogisticRegression()

log_reg.fit(x_train_vec, y_train)
# Out:
# LogisticRegression()

# %%
prediction_training_data = log_reg.predict(x_train_vec)
print(prediction_training_data)
accuracy_train = accuracy_score(y_train,prediction_training_data)
print(f"{accuracy_train * 100:.2f}%")
# Out:
# [1 1 1 ... 1 1 0]
# 96.77%

# %%
prediction_training_data = log_reg.predict(x_test_vec)
print(prediction_training_data)
accuracy_train = accuracy_score(y_test,prediction_training_data)
print(f"{accuracy_train * 100:.2f}%")
# Out:
# [0 1 1 ... 1 1 1]
# 96.68%

# %%
import pickle

# %%
filename = 'spam_ham_model'
pickle.dump(log_reg, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open('spam_ham_model', 'rb'))

# %%
pickle.dump(vectorizer, open('vectorizer.pkl', 'wb'))

# %%
input_mail = ["Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's"]

input_data_features = vectorizer.transform(input_mail)

prediction = loaded_model.predict(input_data_features)
print("Prediction:", prediction)

if prediction[0] == 1:
    print('Ham mail')
else:
    print('Spam mail')
# Out:
# Prediction: [0]
# Spam mail

# %%
input_mail = ["Nah I don't think he goes to usf, he lives around here though"]

input_data_features = vectorizer.transform(input_mail)

prediction = loaded_model.predict(input_data_features)
print("Prediction:", prediction)

if prediction[0] == 1:
    print('Ham mail')
else:
    print('Spam mail')
# Out:
# Prediction: [1]
# Ham mail
